# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
#area of circle usiing math fun
import math
def area_of_circle(r):
    a=math.pi * r**2
    return a
r=float(input('enter the radius'))
area_of_circle(r)
# Out:
# enter the radius12
# 452.3893421169302

# %%
#area of polygon using math fun
from math import tan, pi
def area_of_polygon():
    parea=n_sides*(s_length ** 2)/(4 * tan(pi/n_sides))
    return parea
n_sides=int(input('enter the no of sides:'))
s_length=float(input('enter the length of the side:'))
area_of_polygon()
# Out:
# enter the no of sides:6
# enter the length of the side:12
# 374.1229744348775

# %%
#area of segment of a circle using math fun
def A_of_seg():
    import math
    s=0.5*(ra-math.sin(ra))*r**2
    return s
ra=int(input('enter the radians:'))
r=int(input('enter the radius:'))
A_of_seg()
# Out:
# enter the radians:12
# enter the radius:3
# 56.41457813100195

# %%
import random
l1=[100,1,2,3,30,40,'sai','hello']
print('original list:',l1)
random.shuffle(l1)
print('shuffle list:',l1)
# Out:
# original list: [100, 1, 2, 3, 30, 40, 'sai', 'hello']
# shuffle list: ['hello', 2, 100, 40, 'sai', 3, 30, 1]

# %%
import random
li=random.randrange(1,10000,50)
print('first shuffle',li)
print('secound shuffle',random.randrange(0,10001,50))
print('third shuffle',random.randrange(0,10001,50))
# Out:
# first shuffle 3051
# secound shuffle 2600
# third shuffle 9800

# %%
#functioning of math
import math
print('sin60=',math.sin((math.pi)/3))
print('cos(pi)',math.cos(math.pi))
print('tan90',math.tan(90))
print('anlge for sin of 0.8660254037844386 is ',(math.sin(0.8660254037844386))*57.2958,"degrees")
print('5^8=',(5^8))
print('square root of 400 is=',math.sqrt(400))
print('the value of 5^e is',5^int((math.e)))   
print('the value of log of 1024 for base 2 is=',math.log(1024,2))
print('floor value of 23.56 is', math.floor(23.56))
print('ceil value of 23.56 is', math.ceil(23.56))
# Out:
# sin60= 0.8660254037844386
# cos(pi) -1.0
# tan90 -1.995200412208242
# anlge for sin of 0.8660254037844386 is  43.64564754323142 degrees
# 5^8= 13
# square root of 400 is= 20.0
# the value of 5^e is 7
# the value of log of 1024 for base 2 is= 10.0
# floor value of 23.56 is 23
# ceil value of 23.56 is 24

# %%
import random
l1=[]
l2=[]
for i in range(1,1000):
    x=random.randint(1,1000)
    l1.append(x)
    if i==1:
        l2.append(x)
    k=len(l1)
    l=len(l2)
    if(i>1):
        if abs(l2[l-1]-x)==50:
            l2.append(x)
print(l1)
print(l2)
# Out:
# [199, 272, 747, 264, 857, 506, 402, 343, 531, 355, 623, 65, 683, 517, 246, 967, 924, 941, 122, 644, 994, 368, 379, 800, 139, 264, 35, 311, 481, 559, 392, 81, 74, 567, 886, 856, 737, 815, 369, 444, 69, 569, 764, 454, 341, 389, 320, 916, 209, 796, 935, 676, 646, 60, 699, 409, 619, 839, 894, 438, 996, 680, 182, 846, 718, 318, 381, 690, 145, 258, 188, 619, 127, 193, 797, 219, 973, 379, 808, 349, 767, 441, 355, 550, 918, 638, 360, 112, 698, 262, 374, 500, 242, 459, 705, 649, 36, 665, 21, 461, 19, 545, 394, 221, 568, 270, 384, 340, 374, 52, 578, 223, 931, 48, 806, 985, 397, 403, 919, 993, 937, 425, 42, 230, 204, 819, 289, 349, 604, 355, 456, 976, 255, 674, 363, 566, 259, 336, 659, 732, 404, 357, 295, 26, 82, 380, 822, 559, 761, 923, 641, 223, 269, 513, 817, 415, 649, 439, 127, 344, 531, 9, 520, 851, 799, 85, 598, 760, 185, 564, 60, 495, 836, 76, 784, 912, 663, 973, 428, 463, 649, 962, 946, 51, 899, 824, 446, 225, 766, 707, 922, 253, 514, 435, 190, 998, 577, 416, 446, 206, 333, 754, 134, 55
# ...
